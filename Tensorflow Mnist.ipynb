# %%
from tensorflow.keras.datasets.mnist import load_data
import matplotlib.pyplot as plt
from tensorflow.keras.utils import to_categorical
# Out:
# WARNING:tensorflow:From C:\Users\Varshith\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
(x_train, y_train),(x_test, y_test) = load_data()

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)

# %%
plt.imshow(x_train[0], cmap="gray")
plt.title(y_train[0])
plt.show()

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
x_train = x_train.reshape(60000,784)
x_test = x_test.reshape(10000,784)

# %%
y_train
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
y_train_ohe = to_categorical(y_train)
y_test_ohe = to_categorical(y_test)

# %%
print(x_train.shape)
print(y_train_ohe.shape)
print(x_test.shape)
print(y_test_ohe.shape)
# Out:
# (60000, 784)
# (60000, 10)
# (10000, 784)
# (10000, 10)

# %% [markdown]
# ### Neural Networks using Tensorflow

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense

# %%
model = Sequential()
model.add(Input(784,))
model.add(Dense(10,"softmax"))
# Out:
# WARNING:tensorflow:From C:\Users\Varshith\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics="accuracy")
# Out:
# WARNING:tensorflow:From C:\Users\Varshith\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.fit(x=x_train, y=y_train_ohe, validation_data=(x_test, y_test_ohe), epochs=50, batch_size=1000)
# Out:
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\Varshith\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Varshith\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 60/60 [==============================] - 1s 12ms/step - loss: 34.3823 - accuracy: 0.6109 - val_loss: 10.3045 - val_accuracy: 0.8240
# Epoch 2/50
# 60/60 [==============================] - 0s 7ms/step - loss: 8.9658 - accuracy: 0.8355 - val_loss: 6.9456 - val_accuracy: 0.8568
# Epoch 3/50
# 60/60 [==============================] - 0s 7ms/step - loss: 6.5844 - accuracy: 0.8597 - val_loss: 5.6984 - val_accuracy: 0.8729
# Epoch 4/50
# 60/60 [==============================] - 0s 5ms/step - loss: 5.3700 - accuracy: 0.8709 - val_loss: 4.9011 - val_accuracy: 0.8773
# Epoch 5/50
# 60/60 [==============================] - 0s 6ms/step - loss: 4.6293 - accuracy: 0.8777 - val_loss: 4.4330 - val_accuracy: 0.8777
# Epoch 6/50
# 60/60 [==============================] - 0s 6ms/step - loss: 4.0253 - accuracy: 0.8818 - val_loss: 3.9983 - val_accuracy: 0.8811
# Epoch 7/50
# 60/60 [==============================] - 0s 5ms/step - loss: 3.5866 - accuracy: 0.8867 - val_loss: 3.7852 - val_accuracy: 0.8843
# Epoch 8/50
# 60/60 [==============================] - 0s 4ms/step - loss: 3.2787 - accuracy: 0.8882 - val_loss: 3.5093 - val_accuracy: 0.8839
# Epoch 9/50
# 60/60 [==============================] - 0s 5ms/step - loss: 2.9966 - accuracy: 0.8898 - val_loss: 3.2796 - val_accuracy: 0.8878
# Epoch 10/50
# 60/60 [==============================] - 0s 5ms/step - loss: 2.7430 - accuracy: 0.8929 - val_loss: 3.1141 - val_accuracy: 0.8849
# Epoch 11/50
# 60/60 [==============================] - 0s 5ms/step - loss: 2.5498 - accuracy: 0.8922 - val_loss: 2.9196 - val_accuracy: 0.8883
# Epoch 12/50
# 60/60 [==============================] - 0s 6ms/step - loss: 2.4422 - accuracy: 0.8934 - val_loss: 2.7767 - val_accuracy: 0.8869
# Epoch 13/50
# 60/60 [==============================] - 0s 8ms/step - loss: 2.2849 - accuracy: 0.8940 - val_loss: 2.6360 - val_accuracy: 0.8863
# Epoch 14/50
# 60/60 [==============================] - 1s 9ms/step - loss: 2.1469 - accuracy: 0.8949 - val_loss: 2.6016 - val_accuracy: 0.8861
# Epoch 15/50
# 60/60 [==============================] - 0s 7ms/step - loss: 1.9760 - accuracy: 0.8964 - val_loss: 2.3744 - val_accuracy: 0.8918
# Epoch 16/50
# 60/60 [==============================] - 0s 7ms/step - loss: 1.8890 - accuracy: 0.8967 - val_loss: 2.3650 - val_accuracy: 0.8903
# Epoch 17/50
# 60/60 [==============================] - 0s 5ms/step - loss: 1.8118 - accuracy: 0.8964 - val_loss: 2.1672 - val_accuracy: 0.8912
# Epoch 18/50
# 60/60 [==============================] - 0s 5ms/step - loss: 1.6898 - accuracy: 0.8986 - val_loss: 2.0686 - val_accuracy: 0.8924
# Epoch 19/50
# 60/60 [==============================] - 0s 5ms/step - loss: 1.5918 - accuracy: 0.8967 - val_loss: 2.1353 - val_accuracy: 0.8820
# Epoch 20/50
# 60/60 [==============================] - 0s 4ms/step - loss: 1.5415 - accuracy: 0.8986 - val_loss: 2.1129 - val_accuracy: 0.8845
# Epoch 21/50
# 60/60 [==============================] - 0s 5ms/step - loss: 1.4494 - accuracy: 0.8989 - val_loss: 1.9235 - val_accuracy: 0.8935
# Epoch 22/50
# 60/60 [==============================] - 0s 5ms/step - loss: 1.3984 - accuracy: 0.8998 - val_loss: 1.9290 - val_accuracy: 0.8869
# Epoch 23/50
# 60/60 [==============================] - 0s 5ms/step - loss: 1.3128 - accuracy: 0.9002 - val_loss: 1.8682 - val_accuracy: 0.8910
# Epoch 24/50
# 60/60 [==============================] - 0s 4ms/step - loss: 1.3062 - accuracy: 0.9003 - val_loss: 1.8176 - val_accuracy: 0.8873
# Epoch 25/50
# 60/60 [==============================] - 0s 4ms/step - loss: 1.2188 - accuracy: 0.9016 - val_loss: 1.7999 - val_accuracy: 0.8852
# Epoch 26/50
# 60/60 [==============================] - 0s 5ms/step - loss: 1.2954 - accuracy: 0.8963 - val_loss: 1.6962 - val_accuracy: 0.8968
# Epoch 27/50
# 60/60 [==============================] - 0s 6ms/step - loss: 1.2360 - accuracy: 0.9010 - val_loss: 1.6530 - val_accuracy: 0.8937
# Epoch 28/50
# 60/60 [==============================] - 0s 6ms/step - loss: 1.1071 - accuracy: 0.9021 - val_loss: 1.5237 - val_accuracy: 0.8996
# Epoch 29/50
# 60/60 [==============================] - 0s 4ms/step - loss: 1.1248 - accuracy: 0.9000 - val_loss: 1.5840 - val_accuracy: 0.8938
# Epoch 30/50
# 60/60 [==============================] - 0s 4ms/step - loss: 1.0970 - accuracy: 0.9000 - val_loss: 1.7414 - val_accuracy: 0.8863
# Epoch 31/50
# 60/60 [==============================] - 0s 5ms/step - loss: 1.0636 - accuracy: 0.9018 - val_loss: 1.6630 - val_accuracy: 0.8823
# Epoch 32/50
# 60/60 [==============================] - 0s 5ms/step - loss: 1.0011 - accuracy: 0.9047 - val_loss: 1.5365 - val_accuracy: 0.8877
# Epoch 33/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.9733 - accuracy: 0.9036 - val_loss: 1.4500 - val_accuracy: 0.8910
# Epoch 34/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.9681 - accuracy: 0.9014 - val_loss: 1.3643 - val_accuracy: 0.8985
# Epoch 35/50
# 60/60 [==============================] - 0s 5ms/step - loss: 0.9496 - accuracy: 0.9014 - val_loss: 1.5242 - val_accuracy: 0.8912
# Epoch 36/50
# 60/60 [==============================] - 0s 5ms/step - loss: 0.9503 - accuracy: 0.9040 - val_loss: 1.4251 - val_accuracy: 0.8848
# Epoch 37/50
# 60/60 [==============================] - 0s 5ms/step - loss: 0.8562 - accuracy: 0.9057 - val_loss: 1.2194 - val_accuracy: 0.9018
# Epoch 38/50
# 60/60 [==============================] - 0s 6ms/step - loss: 0.8247 - accuracy: 0.9050 - val_loss: 1.5598 - val_accuracy: 0.8708
# Epoch 39/50
# 60/60 [==============================] - 0s 7ms/step - loss: 0.8748 - accuracy: 0.9023 - val_loss: 1.2392 - val_accuracy: 0.9031
# Epoch 40/50
# 60/60 [==============================] - 0s 7ms/step - loss: 0.8562 - accuracy: 0.9054 - val_loss: 1.2928 - val_accuracy: 0.8898
# Epoch 41/50
# 60/60 [==============================] - 0s 7ms/step - loss: 0.8034 - accuracy: 0.9057 - val_loss: 1.2584 - val_accuracy: 0.8861
# Epoch 42/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.8229 - accuracy: 0.9013 - val_loss: 1.2729 - val_accuracy: 0.8941
# Epoch 43/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.8473 - accuracy: 0.9022 - val_loss: 1.2244 - val_accuracy: 0.8973
# Epoch 44/50
# 60/60 [==============================] - 0s 5ms/step - loss: 0.7920 - accuracy: 0.9043 - val_loss: 1.2067 - val_accuracy: 0.8911
# Epoch 45/50
# 60/60 [==============================] - 0s 5ms/step - loss: 0.7311 - accuracy: 0.9068 - val_loss: 1.0982 - val_accuracy: 0.8963
# Epoch 46/50
# 60/60 [==============================] - 0s 5ms/step - loss: 0.8171 - accuracy: 0.8988 - val_loss: 1.3472 - val_accuracy: 0.8854
# Epoch 47/50
# 60/60 [==============================] - 0s 5ms/step - loss: 0.7677 - accuracy: 0.9062 - val_loss: 1.1842 - val_accuracy: 0.8951
# Epoch 48/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.7496 - accuracy: 0.9052 - val_loss: 1.1122 - val_accuracy: 0.8985
# Epoch 49/50
# 60/60 [==============================] - 0s 5ms/step - loss: 0.7995 - accuracy: 0.9016 - val_loss: 1.1782 - val_accuracy: 0.8892
# Epoch 50/50
# 60/60 [==============================] - 0s 5ms/step - loss: 0.7624 - accuracy: 0.9042 - val_loss: 1.0938 - val_accuracy: 0.8978

# %%
train_loss = model.history.history["loss"]
val_loss = model.history.history["val_loss"]

plt.plot(train_loss)
plt.plot(val_loss)
plt.xlabel("Epochs")
plt.ylabel("Loss")
# plt.ylim((0,500))
plt.legend(["Train", "Test"])
plt.grid()
plt.show()

# %%
train_acc = model.history.history["accuracy"]
val_acc = model.history.history["val_accuracy"]

plt.plot(train_acc)
plt.plot(val_acc)
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["Train", "Test"])
plt.grid()
plt.show()
